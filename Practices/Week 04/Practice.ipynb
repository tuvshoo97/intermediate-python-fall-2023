# %% [markdown]
# ### Step 1: Create a package named `DfCleaner`

# %% [markdown]
# ### Step 2: Read the sample csv file
# * You need to read the `sample_employees.csv` file as a DataFrame and test your functions

# %% [markdown]
# ### Step 3: Create separate functions in `__init__.py`
# 1. import pandas
# 2. `drop_empty` takes pandas dataframe as an input and drops any row with empty value. Use pandas' `dropna`.
#     * Use sample `DataFrame` to test
# 3. `fill_empty` takes pandas dataframe and column name as inputs and fills the given column's empty values using mean. Use pandas' `fillna`.
#     * Use sample `DataFrame` to test
# 4. `drop_column` takes pandas dataframe and column name as inputs and drops the given column and returns the rest of the dataframe. Use pandas' `drop`.
#     * Use sample `DataFrame` to test
# 5. `fix_index` takes pandas dataframe as an input and resets its index and returns it. Use pandas' `reset_index` and drop the old index column.
#     * Use sample `DataFrame` to test
# 6. `fix_dates` takes pandas dataframe and column name as input. Changes given column's data type into datetime. Use pandas' `to_datetime` function.
#     * Use sample `DataFrame` to test

# %% [markdown]
# ### Step 4: CONVERT YOUR PACKAGE INTO A `CLASS` BASED PACKAGE
# #### Create a new file called `cleaner.py` and copy paste `__init__.py`'s code.
# #### Your `__init__.py` must remain empty.
#
# 1. Convert all of your package functions into class *methods*
# 2. Import your package like the following: `from DfCleaner.cleaner import Cleaner`
# 3. Test your class methods using `sample_employees.csv` file

# %%
import DfCleaner
import pandas as pd

# %%
df = pd.read_csv("sample_employees.csv")

# %%
df
# Out:
#     first_name  last_name                           email  gender  \
# 0     Rosamond     Dourin               rdourin0@xing.com  Female
# 1         Mira      Giamo               mgiamo1@ameblo.jp  Female
# 2       August     Nelmes                anelmes2@bbb.org    Male
# 3        Carla  Franzotto                             NaN  Female
# 4        Paxon   Partrick           ppartrick4@drupal.org    Male
# ..         ...        ...                             ...     ...
# 995       Cele    Drennan         cdrennanrn@google.co.uk  Female
# 996     Cristy   Nortunen        cnortunenro@freewebs.com  Female
# 997      Grete    Elcoate  gelcoaterp@merriam-webster.com  Female
# 998    Wilfrid    Canadas                             NaN    Male
# 999   Catriona      Rapps                 crappsrr@nhs.uk  Female
#
#     employed_date            department    salary  bonus
# 0             NaN  Business Development   91048.0   10.0
# 1             NaN                 Legal  146665.0    2.0
# 2        9/7/2014            Accounting  161814.0   14.0
# 3       6/19/2015       Human Resources  168816.0    8.0
# 4       4/15/2018            Accounting  136121.0    NaN
# ..            ...                   ...       ...    ...
# 995           NaN    Product Management  144649.0    NaN
# 996     1/28/2016           Engineering  120389.0    2.0
# 997     5/25/2017               Support   86544.0    NaN
# 998    12/19/2018             Marketing   92586.0    NaN
# 999     3/27/2013             Marketing   93899.0    3.0
#
# [1000 rows x 8 columns]

# %%
# These functions will be moved to __init__.py in DfCleaner later

# %%
# This is the 1st function
def drop_empty(df):
    return df.dropna()

# %%
len(df)
# Out:
# 1000

# %%
len(drop_empty(df))
# Out:
# 464

# %%
df = drop_empty(df)

# %%
for i in range(len(df)):
    print(df['first_name'][i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 2
#       1 for i in range(len(df)):
# ----> 2     print(df['first_name'][i])
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 0

# %%
# This is the 2nd function
def fill_empty(df, column_name):
    return df[column_name].fillna(df[column_name].mean())

# %%
fill_empty(df, 'bonus')
# Out:
# 0      10.000000
# 1       2.000000
# 2      14.000000
# 3       8.000000
# 4       7.699856
#          ...
# 995     7.699856
# 996     2.000000
# 997     7.699856
# 998     7.699856
# 999     3.000000
# Name: bonus, Length: 1000, dtype: float64

# %%
# 3rd function
def drop_column(df, column_name):
    return df.drop(columns=column_name)

# %%
# 4th function
def fix_index(df):
    return df.reset_index(drop=True)

# %%
df = fix_index(df)

# %%
for i in range(len(df)):
    print(df['first_name'][i])
# Out:
# August
# Whittaker
# Timothee
# Shell
# Dill
# Biddy
# Rawley
# Chrissy
# Randie
# Alicea
# Hilliard
# Sisile
# Halie
# Kailey
# Teressa
# Konstantin
# Conway
# Marcia
# Virgilio
# Marie-ann
# Troy
# Kaylil
# Chiarra
# Natasha
# Gram
# Tilda
# Easter
# Georges
# Dodi
# Flinn
# Lorens
# Jonathon
# Fredra
# Horatio
# Anet
# Lanni
# Thorpe
# Teodora
# Alick
# Crissy
# Vinny
# Kimberly
# Brenna
# Granny
# Camella
# Daile
# Free
# Dilan
# Tessi
# Mellie
# Christian
# Elianore
# Sutton
# Philippine
# Thatch
# Giacinta
# Val
# Leoine
# Paige
# Jemimah
# Erin
# Fletcher
# Gawain
# Danica
# Justine
# Isadore
# Hart
# Hoyt
# Papageno
# Laureen
# Jacinthe
# Noble
# Huberto
# Rodolph
# Ellwood
# Carmencita
# Nannie
# Erin
# Kip
# Solomon
# Eloisa
# Nap
# Meredith
# Briana
# Bondy
# Barny
# Albert
# Dolf
# Cacilia
# Ellie
# Hubey
# Laurent
# Francis
# Mehetabel
# Stanislaus
# Erny
# Elnore
# Leanora
# Orrin
# Roxane
# Frederica
# Moises
# Jocelyne
# Kiersten
# Rivkah
# Farlay
# Chan
# Rachel
# Michaella
# Willabella
# Montague
# Elie
# Gayleen
# Mei
# Hermia
# Kurtis
# Tisha
# Niccolo
# Damita
# Cosmo
# Karin
# Isidor
# Godard
# Andriette
# Euell
# Derwin
# Hortensia
# Marcelline
# Sherry
# Bogey
# Paulita
# Avrom
# Chloette
# Rhett
# Lyndsey
# Gregor
# Sarah
# Willow
# Vicki
# Kenton
# Charmine
# Paul
# Sisely
# Jacklin
# Hill
# Hilliard
# Damara
# Jesselyn
# Katrinka
# Mahmud
# Randy
# Raleigh
# Eadmund
# Demetria
# Austen
# Basile
# Rufe
# Reeta
# Odell
# Ingemar
# Marni
# Carree
# Abdel
# Pavel
# Starlin
# Albrecht
# Cortie
# Palmer
# Natalina
# Ingram
# Annice
# Sven
# Bastien
# Martie
# Jeff
# Adelina
# Valaree
# Julie
# Matty
# Clarey
# Nicolais
# Bonita
# Barrett
# Astrid
# Jephthah
# Zerk
# Annabella
# Edik
# Fritz
# Brockie
# Erda
# Donalt
# Emory
# Gilles
# Murray
# Wallie
# Boy
# Mariya
# Gayleen
# Bartholomeus
# Gene
# Jordanna
# Chantalle
# Carleen
# Brnaba
# Kiri
# Daphna
# Graehme
# Aksel
# Brendin
# Tallia
# Ingrid
# Con
# Kassi
# Beryle
# Betsy
# Kippar
# Reg
# Dennison
# Gregoor
# Lelia
# Mohammed
# Karmen
# Colman
# Theadora
# Kerk
# Merwin
# Archy
# Elvyn
# Shelby
# Chaunce
# Gayle
# Auberta
# Emmi
# Romain
# Denys
# Florencia
# Fania
# Ezequiel
# Alfreda
# Myrtia
# Hannis
# Cherrita
# Nellie
# Blayne
# Darice
# Beret
# Yelena
# Kali
# Jakob
# Anthea
# Georgine
# Bride
# Hewet
# Sly
# Gayler
# Claudette
# Georgiana
# Kylie
# Putnem
# Reinwald
# Teddie
# Ashlan
# Rafaellle
# Donny
# Kennett
# Lannie
# Jdavie
# Corbin
# Bettine
# Pierrette
# Kelsey
# Mathilda
# Kristoforo
# Filip
# Tessi
# Lucian
# Sheila-kathryn
# Dedra
# Beaufort
# Joli
# Hamish
# Frazer
# Sheba
# Archaimbaud
# Boyce
# Alyssa
# Basia
# Celka
# Sly
# Milissent
# Cull
# Wes
# Helen
# Gerhardt
# Ellsworth
# Cariotta
# Avis
# Porter
# Dyane
# Kingston
# Barnabas
# Quinton
# Livy
# Michal
# Shara
# Shela
# Jenni
# Kettie
# Ravid
# Saloma
# Tawnya
# Pascal
# Valene
# Maximilien
# Mario
# Jocelyn
# Leoline
# Amandie
# Claudio
# Berk
# Olva
# Gery
# Derk
# Alaric
# Calhoun
# Dru
# Lynnelle
# Birgit
# Dixie
# Shaylyn
# Ardenia
# Pegeen
# Yvon
# Claus
# Leroy
# Jaimie
# Eugenius
# Monah
# Judy
# Sallyann
# Haily
# Brady
# Kassie
# Urbanus
# Hayden
# Genna
# Nate
# Wynny
# Danny
# Doy
# Jonie
# Buddy
# Hilario
# Janeen
# Babbette
# Courtney
# Humfrid
# Monica
# Tabbie
# Tallulah
# Shanna
# Nona
# Micheal
# Linus
# Rosana
# Susanna
# Sallee
# Janaya
# Jsandye
# Earlie
# Sindee
# Katy
# Jefferson
# Bernardine
# Bonny
# Lily
# Gerardo
# Jenn
# Christiana
# Arnie
# Egor
# Aksel
# Sky
# Latrina
# Evin
# Tully
# Timothee
# Luelle
# Vina
# Ansell
# Florence
# Yoko
# Cissiee
# Dale
# Ana
# Katalin
# Lannie
# Mohammed
# Isacco
# Verna
# Faina
# Catrina
# Carling
# Deva
# Rose
# Jolynn
# Daven
# Alfy
# Alberta
# Noelyn
# Jacenta
# Brendin
# Hillier
# Neil
# Devland
# Nikolaos
# Rick
# Camila
# Ana
# Dru
# Trumaine
# Rebbecca
# Sergei
# Judah
# Ivory
# Bunnie
# Lorita
# Joni
# Corrine
# Misha
# Zia
# Paten
# Lizzie
# Devlin
# Prudy
# Annis
# Antonetta
# Kain
# Tonie
# Denice
# Caty
# Wallis
# Darda
# Tonya
# Brigg
# Erena
# Nicolas
# Katti
# Marsh
# Alta
# Brinna
# Rowen
# Krista
# Horace
# Giacomo
# Ruthi
# Shayne
# Domenic
# Theobald
# Franky
# Maurine
# Cristy
# Catriona

# %%
# 5th function
def fix_dates(df, column_name):
    # return df[column_name].to_datetime()
    return pd.to_datetime(df[column_name])

# %%
fix_dates(df, 'employed_date')
# Out:
# 0     2014-09-07
# 1     2018-04-13
# 2     2013-09-05
# 3     2016-02-27
# 4     2018-02-19
#          ...
# 459   2016-05-09
# 460   2017-04-24
# 461   2018-08-15
# 462   2016-01-28
# 463   2013-03-27
# Name: employed_date, Length: 464, dtype: datetime64[ns]

# %%
# TESTING PACKAGE
df = DfCleaner.drop_empty(df)

# %%
df['bonus'] = DfCleaner.fill_empty(df, 'bonus')
# Out:
# /var/folders/7p/ncgl3njd46l8cg9k7s7_hs2m0000gn/T/ipykernel_7725/1337002867.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bonus'] = DfCleaner.fill_empty(df, 'bonus')

# %%
df = DfCleaner.drop_column(df, 'department')

# %%
df = DfCleaner.fix_index(df)

# %%
df['employed_date'] = DfCleaner.fix_dates(df, 'employed_date')

# %%
df
# Out:
#     first_name    last_name                            email  gender  \
# 0       August       Nelmes                 anelmes2@bbb.org    Male
# 1    Whittaker        Cluet            wcluet6@angelfire.com    Male
# 2     Timothee       McVane          tmcvane8@opensource.org    Male
# 3        Shell  Zecchinelli  szecchinellib@blogtalkradio.com    Male
# 4         Dill      Iglesia                   diglesiac@g.co    Male
# ..         ...          ...                              ...     ...
# 459   Theobald       Hatley            thatleyri@state.tx.us    Male
# 460     Franky       McDell          fmcdellrk@pinterest.com  Female
# 461    Maurine      Greeson            mgreesonrl@census.gov  Female
# 462     Cristy     Nortunen         cnortunenro@freewebs.com  Female
# 463   Catriona        Rapps                  crappsrr@nhs.uk  Female
#
#     employed_date    salary  bonus
# 0      2014-09-07  161814.0   14.0
# 1      2018-04-13  114440.0   11.0
# 2      2013-09-05  117430.0    8.0
# 3      2016-02-27  154034.0   13.0
# 4      2018-02-19   64334.0    4.0
# ..            ...       ...    ...
# 459    2016-05-09  175423.0   12.0
# 460    2017-04-24   85666.0   12.0
# 461    2018-08-15   95521.0    7.0
# 462    2016-01-28  120389.0    2.0
# 463    2013-03-27   93899.0    3.0
#
# [464 rows x 7 columns]

# %%
import pandas as pd
from DfCleaner.cleaner import Cleaner

# %%
df = pd.read_csv("sample_employees.csv")
new_df = Cleaner(df)

# %%
new_df.drop_empty()

# %%
new_df.df
# Out:
#     first_name    last_name                            email  gender  \
# 2       August       Nelmes                 anelmes2@bbb.org    Male
# 6    Whittaker        Cluet            wcluet6@angelfire.com    Male
# 8     Timothee       McVane          tmcvane8@opensource.org    Male
# 11       Shell  Zecchinelli  szecchinellib@blogtalkradio.com    Male
# 12        Dill      Iglesia                   diglesiac@g.co    Male
# ..         ...          ...                              ...     ...
# 990   Theobald       Hatley            thatleyri@state.tx.us    Male
# 992     Franky       McDell          fmcdellrk@pinterest.com  Female
# 993    Maurine      Greeson            mgreesonrl@census.gov  Female
# 996     Cristy     Nortunen         cnortunenro@freewebs.com  Female
# 999   Catriona        Rapps                  crappsrr@nhs.uk  Female
#
#     employed_date                department    salary  bonus
# 2        9/7/2014                Accounting  161814.0   14.0
# 6       4/13/2018                  Services  114440.0   11.0
# 8        9/5/2013                   Support  117430.0    8.0
# 11      2/27/2016        Product Management  154034.0   13.0
# 12      2/19/2018                   Support   64334.0    4.0
# ..            ...                       ...       ...    ...
# 990      5/9/2016           Human Resources  175423.0   12.0
# 992     4/24/2017      Business Development   85666.0   12.0
# 993     8/15/2018  Research and Development   95521.0    7.0
# 996     1/28/2016               Engineering  120389.0    2.0
# 999     3/27/2013                 Marketing   93899.0    3.0
#
# [464 rows x 8 columns]

# %%
new_df.fill_empty('bonus')
# Out:
# /Users/amarbayanaltangerel/Desktop/intermediate-python-fall-2023/Practices/Week 04/DfCleaner/cleaner.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df[column_name] = self.df[column_name].fillna(self.df[column_name].mean())

# %%
new_df.drop_column('bonus')

# %%
new_df.df
# Out:
#     first_name    last_name                            email  gender  \
# 2       August       Nelmes                 anelmes2@bbb.org    Male
# 6    Whittaker        Cluet            wcluet6@angelfire.com    Male
# 8     Timothee       McVane          tmcvane8@opensource.org    Male
# 11       Shell  Zecchinelli  szecchinellib@blogtalkradio.com    Male
# 12        Dill      Iglesia                   diglesiac@g.co    Male
# ..         ...          ...                              ...     ...
# 990   Theobald       Hatley            thatleyri@state.tx.us    Male
# 992     Franky       McDell          fmcdellrk@pinterest.com  Female
# 993    Maurine      Greeson            mgreesonrl@census.gov  Female
# 996     Cristy     Nortunen         cnortunenro@freewebs.com  Female
# 999   Catriona        Rapps                  crappsrr@nhs.uk  Female
#
#     employed_date                department    salary
# 2        9/7/2014                Accounting  161814.0
# 6       4/13/2018                  Services  114440.0
# 8        9/5/2013                   Support  117430.0
# 11      2/27/2016        Product Management  154034.0
# 12      2/19/2018                   Support   64334.0
# ..            ...                       ...       ...
# 990      5/9/2016           Human Resources  175423.0
# 992     4/24/2017      Business Development   85666.0
# 993     8/15/2018  Research and Development   95521.0
# 996     1/28/2016               Engineering  120389.0
# 999     3/27/2013                 Marketing   93899.0
#
# [464 rows x 7 columns]
